# %%
import pandas as pd
from pandas import DataFrame

df= pd.read_csv("car_results.csv")

# %%
# delete NAN rows
df = df.dropna()

# %%
newdatasum = df.groupby(['name', 'position','cars_info', 'cars', 'cars_family_info','flat_area', 'flat_area_family', 'house_area', 'house_area_family','income_salary'])
tyg = newdatasum['car_price_usd'].aggregate(sum).reset_index().rename(columns={'car_price_usd': 'cars_sum'})
print tyg

#doesn't work for Єгоров Сергій Олександрович
# Out:
#                                  name  \
# 0        Євграфова Єлизавета Павлівна
# 1        Євграфова Єлизавета Павлівна
# 2             Євлах Оксана Олексіївна
# 3         Євлахов Анатолій Сергійович
# 4         Євлахов Анатолій Сергійович
# 5        Євстигнеєва Надія Михайлівна
# 6        Євстигнеєва Надія Михайлівна
# 7        Євсік Володимир Анатолійович
# 8       Євсіков Олексій Олександрович
# 9           Євтушенко Ірина Борисівна
# 10           Євтушенко Олена Іванівна
# 11           Євтушенко Олена Іванівна
# 12        Євтушенко Світлана Олегівна
# 13      Євтушенко Сергій Анатолійович
# 14        Єгоров Сергій Олександрович
# 15       Єлфімов Олександр Васильович
# 16       Єлфімов Олександр Васильович
# 17    Єлісєєв Володимир Олександрович
# 18      Ємельянова Валентина Іванівна
# 19        Ємець Анатолій Анатолійович
# 20        Ємець Віталій Володимирович
# 21            Ємчук Віктор Едуардович
# 22              Єна Андрій Леонідович
# ...

# %%
carMagnats  = tyg[tyg.cars_sum > 100000]
carMagnats

# test = tyg.sort('sum', ascending=True)
# test
# Out:
#                                        name  \
# 26                   Єремеєв Ігор Миронович
# 68             Іванчук Андрій Володимирович
# 74            Іванющенко Юрій Володимирович
# 120               Ільюк Артем Олександрович
# 178                Алєксєєв Сергій Олегович
# 238          Аркаллаєв Нуруліслам Гаджиєвич
# 258        Атрошенко Владислав Анатолійович
# 394               Березенко Сергій Іванович
# 395               Березенко Сергій Іванович
# 689                    Білоус Ігор Олегович
# 1140           Гонтарева Валерія Олексіївна
# 1141           Гонтарева Валерія Олексіївна
# 1304           Гройсман Володимир Борисович
# 1470                Демянко Микола Іванович
# 1494             Дерев’янко Юрій Богданович
# 1495             Дерев’янко Юрій Богданович
# 1496             Дерев’янко Юрій Богданович
# 1548                Добкін Михайло Маркович
# 1549                Добкін Михайло Маркович
# 1684                  Жванія Давид Важаєвич
# ...

# %%
carMagnats['cars_sum'] = carMagnats['cars_sum'].round(0)
carMagnats['income_salary'] = carMagnats['income_salary'].round(0)
# car2 = carMagnats['cars_family_info'].str.replace('\b\;\b', ', ', case=False)
carMagnats
# Out:
# C:\Users\Yaryna\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Yaryna\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                                        name  \
# 26                   Єремеєв Ігор Миронович
# 68             Іванчук Андрій Володимирович
# 74            Іванющенко Юрій Володимирович
# ...

# %%
carMagnats['montly_salary'] = carMagnats.income_salary/12
carMagnats['montly_salary'] = carMagnats['montly_salary'].round(0)
carMagnats
# Out:
# C:\Users\Yaryna\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Yaryna\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                                        name  \
# 26                   Єремеєв Ігор Миронович
# 68             Іванчук Андрій Володимирович
# 74            Іванющенко Юрій Володимирович
# ...

# %%
poorCarMagnats  = carMagnats[carMagnats.montly_salary < 100000]
poorCarMagnats
# Out:
#                                        name  \
# 26                   Єремеєв Ігор Миронович
# 68             Іванчук Андрій Володимирович
# 74            Іванющенко Юрій Володимирович
# 120               Ільюк Артем Олександрович
# 178                Алєксєєв Сергій Олегович
# 238          Аркаллаєв Нуруліслам Гаджиєвич
# 258        Атрошенко Владислав Анатолійович
# 394               Березенко Сергій Іванович
# 395               Березенко Сергій Іванович
# 689                    Білоус Ігор Олегович
# 1140           Гонтарева Валерія Олексіївна
# 1304           Гройсман Володимир Борисович
# 1470                Демянко Микола Іванович
# 1494             Дерев’янко Юрій Богданович
# 1495             Дерев’янко Юрій Богданович
# 1496             Дерев’янко Юрій Богданович
# 1548                Добкін Михайло Маркович
# 1549                Добкін Михайло Маркович
# 1684                  Жванія Давид Важаєвич
# 1685                  Жванія Давид Важаєвич
# ...

# %%
carMagnatsData = carMagnats.to_csv('game_data.csv')
